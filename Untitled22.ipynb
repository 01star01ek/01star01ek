# %% [markdown]
# <a href="https://colab.research.google.com/github/01star01ek/01star01ek/blob/main/Untitled22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf /content/results

# %%
# ▶️ Git 클론 및 환경 설치
# %cd /content
# !git clone https://github.com/woctezuma/SimSwap.git
# %cd /content/SimSwap
# !git checkout upgrade-insightface

# !pip install insightface==0.7.3 onnxruntime moviepy > /dev/null
# !pip install imageio==2.34.0 > /dev/null

# ▶️ 모델 및 리소스 다운로드
# !wget https://github.com/woctezuma/SimSwap-colab/releases/download/antelope/antelope.zip
# !wget -P ./arcface_model https://github.com/woctezuma/SimSwap-colab/releases/download/1.0/arcface_checkpoint.tar
# !wget https://github.com/neuralchen/SimSwap/releases/download/1.0/checkpoints.zip
# !wget -P ./parsing_model/checkpoint https://github.com/neuralchen/SimSwap/releases/download/1.0/79999_iter.pth
# !wget https://github.com/neuralchen/SimSwap/releases/download/512_beta/512.zip

# ▶️ 압축 해제
# !unzip -oq checkpoints.zip -d ./checkpoints
# !unzip -oq 512.zip -d ./checkpoints
# !unzip -oq antelope.zip -d ./insightface_func/models/
# Out:
# /content
# fatal: destination path 'SimSwap' already exists and is not an empty directory.
# /content/SimSwap
# Already on 'upgrade-insightface'
# Your branch is up to date with 'origin/upgrade-insightface'.
# --2025-06-17 05:01:58--  https://github.com/woctezuma/SimSwap-colab/releases/download/antelope/antelope.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# ▶️ SimSwap 경로 설정
# %cd /content/SimSwap

import sys
sys.path.append('/content/SimSwap')

import os
import cv2
import torch
import torch.nn.functional as F
from PIL import Image
from torchvision import transforms
from models.models import create_model
from options.test_options import TestOptions
from insightface_func.face_detect_crop_multi import Face_detect_crop
from util.videoswap import video_swap

# ▶️ PyTorch 2.6+ 보안 대응 - 모델 클래스 허용
from torch.serialization import add_safe_globals
from models.arcface_models import ResNet, IRBlock, SEBlock
from torch.nn import (
    Conv2d, BatchNorm2d, BatchNorm1d, PReLU, MaxPool2d, Sequential,
    ReLU, Linear, AdaptiveAvgPool2d, Dropout, Module, Sigmoid
)

add_safe_globals([
    Conv2d, BatchNorm2d, BatchNorm1d, PReLU, MaxPool2d, Sequential,
    ReLU, Linear, AdaptiveAvgPool2d, Dropout, Module, Sigmoid,
    ResNet, IRBlock, SEBlock
])

# %%
# ▶️ 기본 설정
crop_size = 512  # 정확도 유지용
det_thresh = 0.6
det_size = (640, 640)

# ▶️ 얼굴 임베딩용 변환기
transformer_Arcface = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %%
# ▶️ SimSwap 옵션 설정
opt = TestOptions()
opt.initialize()
opt.parser.add_argument('-f')  # for Colab compatibility
opt = opt.parse()
opt.isTrain = False
opt.no_simswaplogo = True
opt.use_mask = True
opt.crop_size = crop_size
opt.Arc_path = './arcface_model/arcface_checkpoint.tar'
opt.name = '512' if crop_size == 512 else 'people'
opt.which_epoch = 550000 if crop_size == 512 else 'latest'
mode = 'ffhq' if crop_size == 512 else 'None'

# ▶️ 모델 생성 및 얼굴 인식기 준비
torch.nn.Module.dump_patches = True
model = create_model(opt)
model.eval()

app = Face_detect_crop(name='antelope', root='./insightface_func/models')
app.prepare(ctx_id=0, det_thresh=det_thresh, det_size=det_size, mode=mode)

# %%
import os
import cv2
from PIL import Image
import torch.nn.functional as F

# ▶️ 입력/출력 경로
video_dir = '/content/videos'
photo_dir = '/content/photos'
output_root = '/content/results'

# ▶️ 파일 목록 (정렬된 순서로 매칭)
video_files = sorted([f for f in os.listdir(video_dir) if f.endswith('.mp4')])
photo_files = sorted([f for f in os.listdir(photo_dir) if f.endswith(('.png', '.jpg', '.jpeg'))])

# ▶️ 순서 기준 매칭
num_files = min(len(video_files), len(photo_files))

for i in range(num_files):
    video_file = video_files[i]
    photo_file = photo_files[i]

    video_id = str(i + 1).zfill(4)  # 0001, 0002, ...
    temp_path = os.path.join(output_root, f"tmp_{video_id}")
    output_path = os.path.join(temp_path, f"result_{video_id}.mp4")  # ✅ tmp 폴더 안에 저장

    # ✅ temp 폴더 생성
    os.makedirs(temp_path, exist_ok=True)

    # ✅ 실제 경로 지정
    input_video = os.path.join(video_dir, video_file)
    photo_path = os.path.join(photo_dir, photo_file)

    opt.video_path = input_video
    opt.pic_a_path = photo_path
    opt.output_path = output_path
    opt.temp_path = temp_path

    # ▶ 얼굴 임베딩 생성
    img_a_whole = cv2.imread(photo_path)
    result = app.get(img_a_whole, opt.crop_size)

    if result is None:
        h, w, _ = img_a_whole.shape
        center = (w // 2, h // 2)
        half = opt.crop_size // 2
        cropped = img_a_whole[max(0, center[1]-half):center[1]+half,
                              max(0, center[0]-half):center[0]+half]
        img_pil = Image.fromarray(cv2.cvtColor(cropped, cv2.COLOR_BGR2RGB))
    else:
        img_align, _ = result
        img_pil = Image.fromarray(cv2.cvtColor(img_align[0], cv2.COLOR_BGR2RGB))

    img_a = transformer_Arcface(img_pil).unsqueeze(0).cuda()
    img_id_downsample = F.interpolate(img_a, size=(112, 112))
    latend_id = model.netArc(img_id_downsample)
    latend_id = F.normalize(latend_id, p=2, dim=1)

    # ▶ 얼굴 교체 실행
    video_swap(input_video, latend_id, model, app, output_path,
               temp_results_dir=temp_path,
               no_simswaplogo=opt.no_simswaplogo,
               use_mask=opt.use_mask,
               crop_size=opt.crop_size)

    print(f"[✅] 완료: {video_id} → {output_path}")
# Out:
# (142, 366, 4)
#   0%|          | 0/469 [00:00<?, ?it/s]WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
#
# 100%|██████████| 469/469 [02:12<00:00,  3.54it/s]
# Moviepy - Building video /content/results/tmp_0001/result_0001.mp4.
# Moviepy - Writing video /content/results/tmp_0001/result_0001.mp4
# Moviepy - Done !
# Moviepy - video ready /content/results/tmp_0001/result_0001.mp4
# [✅] 완료: 0001 → /content/results/tmp_0001/result_0001.mp4
# (142, 366, 4)
# 100%|██████████| 303/303 [01:26<00:00,  3.52it/s]
# Moviepy - Building video /content/results/tmp_0002/result_0002.mp4.
# Moviepy - Writing video /content/results/tmp_0002/result_0002.mp4
# Moviepy - Done !
# ...

# %%
import os
from glob import glob

# 🔧 경로 설정
output_root = "/content/results"
tmp_dirs = sorted(glob(os.path.join(output_root, "tmp_*")))

print(f"총 {len(tmp_dirs)}개 영상 후처리 시작")

for i, tmp_dir in enumerate(tmp_dirs):
    base_id = tmp_dir.split("_")[-1]  # 'tmp_0001' → '0001'

    result_path  = os.path.join(tmp_dir, f"result_{base_id}.mp4")
    denoise_path = os.path.join(tmp_dir, f"denoise_{base_id}.mp4")
    sharpen_path = os.path.join(tmp_dir, f"sharpen_{base_id}.mp4")
    final_path   = os.path.join(tmp_dir, f"final_{base_id}.mp4")

    print(f"\n▶️ [{i+1}/{len(tmp_dirs)}] result_{base_id}.mp4 후처리 중...")

    if not os.path.exists(result_path):
        print(f"⚠️ result_{base_id}.mp4 없음 → 건너뜀")
        continue

    # 노이즈 제거
    print(" - 노이즈 제거 중...")
    os.system(f'ffmpeg -y -i "{result_path}" -vf "hqdn3d=4.0:3.0:6.0:4.5" -c:a copy "{denoise_path}"')

    # 선명화
    print(" - 선명화 중...")
    os.system(f'ffmpeg -y -i "{denoise_path}" -vf "unsharp=5:5:1.0:5:5:0.0" -c:a copy "{sharpen_path}"')

    # 최종 출력 (30fps + 고화질 압축)
    print(" - 최종 인코딩 중...")
    os.system(f'ffmpeg -y -i "{sharpen_path}" -filter:v "fps=30" -c:v libx264 -preset slow -crf 18 -pix_fmt yuv420p "{final_path}"')

    print(f"✅ 저장 완료 → {final_path}")

# %%
# NumPy 버전 다운 (중요!)
# !pip install numpy==1.24.4

# Real-ESRGAN 초기화
# %cd /content
# !rm -rf Real-ESRGAN
# !git clone https://github.com/xinntao/Real-ESRGAN.git
# %cd Real-ESRGAN
# !pip install basicsr facexlib gfpgan
# !pip install -r requirements.txt
# !python setup.py develop
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# The folder you are executing pip from can no longer be found.
# /content
# Cloning into 'Real-ESRGAN'...
# remote: Enumerating objects: 759, done.
# remote: Counting objects: 100% (121/121), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 759 (delta 106), reused 99 (delta 99), pack-reused 638 (from 1)
# Receiving objects: 100% (759/759), 5.38 MiB | 10.93 MiB/s, done.
# Resolving deltas: 100% (415/415), done.
# /content/Real-ESRGAN
# ...
# /usr/local/lib/python3.11/dist-packages/setuptools/__init__.py:94: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
# !!
#
#         ********************************************************************************
# ...

# %%
import os

os.makedirs("video_upload", exist_ok=True)
os.makedirs("frames_raw", exist_ok=True)
os.makedirs("frames_sr", exist_ok=True)

# %%
from google.colab import files
uploaded = files.upload()

# 예: 비디오 저장
import shutil
for name in uploaded:
    shutil.move(name, f"video_upload/{name}")
# Out:
#      <input type="file" id="files-2825bce4-4cee-463f-a923-46e4945afdaf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2825bce4-4cee-463f-a923-46e4945afdaf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
os.rename("video_upload/final_0001 (2).mp4", "video_upload/final_0001.mp4")

# %%
# !ffmpeg -i video_upload/final_0001.mp4 frames_raw/frame_%05d.png
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
# !pip install numpy==1.24.4 --force-reinstall
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 106.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 1.24.4 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.24.4 which is incompatible.
# blosc2 3.3.4 requires numpy>=1.26, but you have numpy 1.24.4 which is incompatible.
# treescope 0.1.9 requires numpy>=1.25.2, but you have numpy 1.24.4 which is incompatible.
# jaxlib 0.5.1 requires numpy>=1.25, but you have numpy 1.24.4 which is incompatible.
# jax 0.5.2 requires numpy>=1.25, but you have numpy 1.24.4 which is incompatible.
# ...

# %%
# %cd /content/Real-ESRGAN
# !python inference_realesrgan.py -n RealESRGAN_x4plus -i frames_raw --outscale 3.5 --face_enhance
# Out:
# /content/Real-ESRGAN
# /usr/local/lib/python3.11/dist-packages/torchvision/transforms/functional_tensor.py:5: UserWarning: The torchvision.transforms.functional_tensor module is deprecated in 0.15 and will be **removed in 0.17**. Please don't rely on it. You probably just need to use APIs in torchvision.transforms.functional or in torchvision.transforms.v2.functional.
#   warnings.warn(
# Downloading: "https://github.com/xinntao/Real-ESRGAN/releases/download/v0.1.0/RealESRGAN_x4plus.pth" to /content/Real-ESRGAN/weights/RealESRGAN_x4plus.pth
#
# 100% 63.9M/63.9M [00:00<00:00, 289MB/s]
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# ...

# %%
# !ffmpeg -framerate 30 -i /content/frames_raw_001/frame_%05d.png -c:v libx264 -pix_fmt yuv420p result_upscaled.mp4
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
from google.colab import files
files.download('result_upscaled.mp4')

# %%
# !pip install mediapipe opencv-python-headless

# %%
import os
import shutil
from google.colab import files

# 폴더 정리
video_dir = '/content/video_upload'
frames_dir = '/content/frames_raw'
blended_dir = '/content/frames_blended'
os.makedirs(video_dir, exist_ok=True)
os.makedirs(frames_dir, exist_ok=True)
os.makedirs(blended_dir, exist_ok=True)

# 사용자에게 영상 업로드 받기
print("🎬 합성할 영상 파일을 업로드하세요")
uploaded = files.upload()
for fname in uploaded.keys():
    shutil.move(fname, os.path.join(video_dir, 'input_video.mp4'))

# GAN 얼굴 이미지 업로드 받기
print("🧠 GAN으로 생성된 얼굴 이미지를 업로드하세요 (예: face.png)")
uploaded = files.upload()
for fname in uploaded.keys():
    shutil.move(fname, '/content/GAN_FACE.png')
# Out:
# 🎬 합성할 영상 파일을 업로드하세요
#      <input type="file" id="files-46188f42-40e2-4e15-a33e-2df3231fab63" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-46188f42-40e2-4e15-a33e-2df3231fab63">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
# 영상 프레임 추출
# !ffmpeg -i /content/video_upload/input_video.mp4 -qscale:v 2 /content/frames_raw/frame_%05d.png
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
import cv2
import numpy as np
import os
import mediapipe as mp

# 경로 설정
input_dir = '/content/frames_raw'
output_dir = '/content/frames_blended'
gan_face_path = '/content/GAN_FACE.png'

# GAN 얼굴 이미지 로드 및 resize
gan_face = cv2.imread(gan_face_path)
gan_face = cv2.resize(gan_face, (256, 256))

# Mediapipe 초기화
mp_face_mesh = mp.solutions.face_mesh
face_mesh = mp_face_mesh.FaceMesh(static_image_mode=True)

# fallback용 이전 center
prev_center = None

# 프레임 반복 처리
for fname in sorted(os.listdir(input_dir)):
    if not fname.endswith('.png'):
        continue

    frame_path = os.path.join(input_dir, fname)
    frame = cv2.imread(frame_path)
    h, w = frame.shape[:2]

    # 랜드마크 인식
    results = face_mesh.process(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    if not results.multi_face_landmarks:
        if prev_center is None:
            print(f"❌ 첫 프레임 인식 실패 (skip): {fname}")
            continue
        center = prev_center
        print(f"⚠️ 인식 실패: {fname}, 이전 center 사용")
    else:
        landmarks = results.multi_face_landmarks[0]
        points = np.array([[int(p.x * w), int(p.y * h)] for p in landmarks.landmark])
        center_x = int(np.mean(points[33:133, 0]))
        center_y = int(np.mean(points[33:133, 1]))
        center = (center_x, center_y)
        prev_center = center

    # 마스크 생성
    mask = 255 * np.ones(gan_face.shape, gan_face.dtype)

    # blending
    blended = cv2.seamlessClone(
        gan_face, frame, mask, center, cv2.NORMAL_CLONE
    )

    save_path = os.path.join(output_dir, fname)
    cv2.imwrite(save_path, blended)
    print(f"✅ 완료: {fname}")
# Out:
# ✅ 완료: frame_00001.png
# ✅ 완료: frame_00002.png
# ✅ 완료: frame_00003.png
# ✅ 완료: frame_00004.png
# ✅ 완료: frame_00005.png
# ✅ 완료: frame_00006.png
# ✅ 완료: frame_00007.png
# ✅ 완료: frame_00008.png
# ✅ 완료: frame_00009.png
# ✅ 완료: frame_00010.png
# ✅ 완료: frame_00011.png
# ✅ 완료: frame_00012.png
# ✅ 완료: frame_00013.png
# ✅ 완료: frame_00014.png
# ✅ 완료: frame_00015.png
# ⚠️ 인식 실패: frame_00016.png, 이전 center 사용
# ✅ 완료: frame_00016.png
# ✅ 완료: frame_00017.png
# ✅ 완료: frame_00018.png
# ⚠️ 인식 실패: frame_00019.png, 이전 center 사용
# ✅ 완료: frame_00019.png
# ⚠️ 인식 실패: frame_00020.png, 이전 center 사용
# ✅ 완료: frame_00020.png
# ⚠️ 인식 실패: frame_00021.png, 이전 center 사용
# ✅ 완료: frame_00021.png
# ✅ 완료: frame_00022.png
# ⚠️ 인식 실패: frame_00023.png, 이전 center 사용
# ✅ 완료: frame_00023.png
# ✅ 완료: frame_00024.png
# ✅ 완료: frame_00025.png
# ⚠️ 인식 실패: frame_00026.png, 이전 center 사용
# ✅ 완료: frame_00026.png
# ✅ 완료: frame_00027.png
# ✅ 완료: frame_00028.png
# ⚠️ 인식 실패: frame_00029.png, 이전 center 사용
# ✅ 완료: frame_00029.png
# ...

# %%
# !ffmpeg -framerate 30 -i /content/frames_blended/frame_%05d.png -c:v libx264 -pix_fmt yuv420p /content/blended_result.mp4
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
from google.colab import files
files.download('/content/blended_result.mp4')

# %%
# !pip install opencv-python mediapipe torch torchvision tqdm einops ninja hydra-core scipy

# 필요한 저장소 clone
# !git clone https://github.com/omertov/encoder4editing.git
# !git clone https://github.com/NVlabs/stylegan3.git
# %cd stylegan3
# !pip install -r requirements.txt
# %cd ..
# Out:
# ...
# Cloning into 'encoder4editing'...
# remote: Enumerating objects: 172, done.
# remote: Counting objects: 100% (79/79), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 172 (delta 50), reused 44 (delta 44), pack-reused 93 (from 1)
# Receiving objects: 100% (172/172), 32.98 MiB | 25.64 MiB/s, done.
# Resolving deltas: 100% (59/59), done.
# Cloning into 'stylegan3'...
# remote: Enumerating objects: 212, done.
# remote: Counting objects: 100% (166/166), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 212 (delta 101), reused 96 (delta 96), pack-reused 46 (from 1)
# Receiving objects: 100% (212/212), 4.16 MiB | 9.01 MiB/s, done.
# Resolving deltas: 100% (107/107), done.
# /content/SimSwap/stylegan3
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# /content/SimSwap

# %%
from google.colab import files
import os

os.makedirs("video_upload", exist_ok=True)
os.makedirs("gan_upload", exist_ok=True)

print("🎥 영상 업로드:")
video_file = files.upload()
video_path = list(video_file.keys())[0]
os.rename(video_path, f'video_upload/{video_path}')

print("🖼️ GAN 이미지 업로드:")
gan_file = files.upload()
gan_img_path = list(gan_file.keys())[0]
os.rename(gan_img_path, f'gan_upload/{gan_img_path}')
# Out:
# 🎥 영상 업로드:
#      <input type="file" id="files-d26b649b-6a57-489b-a406-3fe7f72a76b0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d26b649b-6a57-489b-a406-3fe7f72a76b0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
# !mkdir -p frames_raw
# !ffmpeg -i "video_upload/{video_path}" -vf fps=30 "frames_raw/frame_%05d.png"
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
# pretrained 모델 다운로드 (한 번만)
# !gdown --id 1zMJbU8-WzK1eJ3v9mG0gYQy2OFiQeUGX -O encoder4editing/pretrained_models/e4e_ffhq_encode.pt

# GAN 얼굴 인코딩
# !python encoder4editing/scripts/inference_playground.py \
  --checkpoint_path encoder4editing/pretrained_models/e4e_ffhq_encode.pt \
  --input_imgs "gan_upload/{gan_img_path}" \
  --output_dir gan_encoded

# 영상 프레임 인코딩
# !python encoder4editing/scripts/inference_playground.py \
  --checkpoint_path encoder4editing/pretrained_models/e4e_ffhq_encode.pt \
  --input_imgs frames_raw \
  --output_dir frames_encoded
# Out:
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Failed to retrieve file url:
#
# 	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
# 	Check FAQ in https://github.com/wkentaro/gdown?tab=readme-ov-file#faq.
#
# You may still be able to access the file from the browser:
#
# 	https://drive.google.com/uc?id=1zMJbU8-WzK1eJ3v9mG0gYQy2OFiQeUGX
#
# but Gdown can't. Please check connections and permissions.
# python3: can't open file '/content/encoder4editing/encoder4editing/scripts/inference_playground.py': [Errno 2] No such file or directory
# python3: can't open file '/content/encoder4editing/encoder4editing/scripts/inference_playground.py': [Errno 2] No such file or directory

# %%
# Step 1. 설치 및 경로 설정
# !git clone https://github.com/NVlabs/stylegan3.git
# !pip install ninja imageio imageio-ffmpeg scipy

# Python에서 stylegan3 내부 모듈들 import 가능하게 만들기
import sys
sys.path.append('/content/stylegan3')
# Out:
# fatal: destination path 'stylegan3' already exists and is not an empty directory.
# ...

# %%
# !mkdir -p stylegan3/pretrained
# !wget https://nvlabs-fi-cdn.nvidia.com/stylegan3/networks/stylegan3-r-ffhq-1024x1024.pkl -O stylegan3/pretrained/stylegan3-r-ffhq-1024x1024.pkl
# Out:
# --2025-06-17 03:36:18--  https://nvlabs-fi-cdn.nvidia.com/stylegan3/networks/stylegan3-r-ffhq-1024x1024.pkl
# Resolving nvlabs-fi-cdn.nvidia.com (nvlabs-fi-cdn.nvidia.com)... 216.137.39.99, 216.137.39.37, 216.137.39.20, ...
# Connecting to nvlabs-fi-cdn.nvidia.com (nvlabs-fi-cdn.nvidia.com)|216.137.39.99|:443... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2025-06-17 03:36:18 ERROR 403: Forbidden.

# %%
import sys
sys.path.append('/content/stylegan3')

from dnnlib import legacy
import torch
import numpy as np
import os
from PIL import Image
from tqdm import tqdm

# StyleGAN3 G 로드
with open('/content/stylegan3/pretrained/stylegan3-r-ffhq-1024x1024.pkl', 'rb') as f:
    G = legacy.load_network_pkl(f)['G_ema'].cuda()

def load_latent(path):
    return torch.load(path)['latent'].cuda()

gan_latent = load_latent('gan_encoded/latent.pt')
os.makedirs('stylized_frames', exist_ok=True)

encoded_files = sorted([f for f in os.listdir('frames_encoded') if f.endswith('.pt')])

for fname in tqdm(encoded_files):
    frame_latent = load_latent(f'frames_encoded/' + fname)

    # blending: pose는 영상, 스타일은 GAN 얼굴
    mixed = 0.5 * gan_latent + 0.5 * frame_latent

    img = G.synthesis(mixed, noise_mode='const')[0]
    img = (img.clamp(-1, 1) + 1) * 127.5
    img = img.permute(1, 2, 0).cpu().numpy().astype(np.uint8)
    Image.fromarray(img).save(f'stylized_frames/{fname.replace(".pt", ".png")}')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-32-2808788617> in <cell line: 0>()
#       2 sys.path.append('/content/stylegan3')
#       3
# ----> 4 from dnnlib import legacy
#       5 import torch
#       6 import numpy as np
#
# ModuleNotFoundError: No module named 'dnnlib'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !ffmpeg -framerate 30 -i stylized_frames/frame_%05d.png -c:v libx264 -pix_fmt yuv420p output_video.mp4
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
from google.colab import files
files.download("output_video.mp4")
