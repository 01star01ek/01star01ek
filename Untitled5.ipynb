# %% [markdown]
# <a href="https://colab.research.google.com/github/01star01ek/01star01ek/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python main.py
# Out:
# 🚀 Starting Romance Scam Detection Experiment!
#    Results will be saved in: 'final_results/20250613_030351'
# ✅ 실제 데이터 로딩 시작: 'normal_pre_final.json', 'scam_pre_final.json'
# ✅ 데이터 로딩 완료: 총 9863개 프로필 (정상: 8985, 스캠: 878)
# 📊 데이터 분할 완료:
#   - 학습용(최적화): 7125개 (Scam: 634)
#   - 검증용(최적화): 1258개 (Scam: 112)
#   - 최종학습용(Train+Val): 8383개 (Scam: 746)
#   - 최종평가용(Test): 1480개 (Scam: 132)
#
# 🔍 Step 1: Optimizing Text Feature Dimensions
#   Experimenting with: {'desc_dim': 8, 'occ_dim': 4}
#     => Validation AUC: 0.9903
#   Experimenting with: {'desc_dim': 8, 'occ_dim': 8}
#     => Validation AUC: 0.9916
#   Experimenting with: {'desc_dim': 8, 'occ_dim': 12}
#     => Validation AUC: 0.9919
#   Experimenting with: {'desc_dim': 8, 'occ_dim': 16}
#     => Validation AUC: 0.9872
#   Experimenting with: {'desc_dim': 8, 'occ_dim': 24}
#     => Validation AUC: 0.9912
#   Experimenting with: {'desc_dim': 8, 'occ_dim': 32}
#     => Validation AUC: 0.9920
# ...

# %%
# !python create_extra_plots.py
# Out:
# Report loaded successfully from 'final_results/20250613_030351/final_report.json'.
# 📊 Generating additional analysis visualizations...
#   ✨ 1. Generating Scenario-wise Precision-Recall (PR) Curves...
#   ✅ 1. PR Curves saved: final_results/20250613_030351/additional_figures/figure_pr_curve_by_scenario.png
#   ✨ 2. Generating Detailed Performance Comparison Table...
# /content/plotting.py:240: UserWarning: Glyph 127942 (\N{TROPHY}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path, dpi=300, bbox_inches='tight', pad_inches=0.5)
#   ✅ 2. Detailed performance table saved: final_results/20250613_030351/additional_figures/table_detailed_performance_comparison.png
#   ✨ 3. Generating Reconstruction Error Distribution (Zero-Shot)...
#   ✅ 3. Reconstruction error distribution plot saved: final_results/20250613_030351/additional_figures/figure_reconstruction_error_distribution.png
#   ✨ 4. Generating Hyperparameter Sensitivity Analysis...
# /content/plotting.py:314: FutureWarning:
# ...
